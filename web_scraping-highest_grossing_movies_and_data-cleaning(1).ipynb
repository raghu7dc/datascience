# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from unicodedata import normalize
# %matplotlib inline

# %% [markdown]
# # web scraping using read_html

# %%
#creating a table variable with URL and setting the argument to "match" parameter

table_movies=pd.read_html('https://en.wikipedia.org/wiki/List_of_highest-grossing_films',match='Highest-grossing films')

# %%
# Total number of tables matching our requirement

len(table_movies)
# Out:
# 4

# %%
#importing tables by using their indexes\

table_movies[0].head()
# Out:
#    Rank Peak                         Title Worldwide gross  Year Reference(s)
# 0     1    1                        Avatar  $2,847,246,203  2009   [# 1][# 2]
# 1     2    1             Avengers: Endgame  $2,797,501,328  2019   [# 3][# 4]
# 2     3    1                       Titanic  $2,187,425,379  1997   [# 5][# 6]
# 3     4    3  Star Wars: The Force Awakens  $2,068,223,624  2015   [# 7][# 8]
# 4     5    4        Avengers: Infinity War  $2,048,359,754  2018  [# 9][# 10]

# %%
table_movies[1].head()
# Out:
#    Rank               Title Worldwide gross(2020 $)  Year
# 0     1  Gone with the Wind          $3,739,000,000  1939
# 1     2              Avatar         A$3,286,000,000  2009
# 2     3             Titanic         T$3,108,000,000  1997
# 3     4           Star Wars          $3,071,000,000  1977
# 4     5   Avengers: Endgame        AE$2,823,000,000  2019

# %%
table2=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_films",match='Highest-grossing franchises and film series')

# %%
len(table2)
# Out:
# 1

# %%
table2[0].head()
# Out:
#                                                    0  \
# 1                                               Rank
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                                  1
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                                NaN
#
#                                                    1  \
# 1                                             Series
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                         Marvel Cinematic UniverseS
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                  The Infinity Saga
#
#                                                    2  \
# 1                              Total worldwide gross
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                    $23,332,172,582
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# ...

# %%
df=table2[0]

# %%
#selecting the row we want to be new header
row_header=df.loc[1]

# %%
#dropping the header row from the data
data=df.drop([1])

# %%
data.head()
# Out:
#                                                    0  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                                  1
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                                NaN
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                                    1  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                         Marvel Cinematic UniverseS
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                  The Infinity Saga
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                                    2  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                    $23,332,172,582
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                    $22,587,903,034
# ...

# %%
#this did not work
data.coulmns=new_header
# Out:
# C:\Users\Raghu\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
data.head()
# Out:
#                                                    0  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                                  1
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                                NaN
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                                    1  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                         Marvel Cinematic UniverseS
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                  The Infinity Saga
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                                    2  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                    $23,332,172,582
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                    $22,587,903,034
# ...

# %%
#method to rename our row header 
data.rename(columns=df.loc[1],inplace=True)

# %%
data.head()
# Out:
#                                                 Rank  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                                  1
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                                NaN
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                               Series  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                         Marvel Cinematic UniverseS
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                  The Infinity Saga
# 6  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                Total worldwide gross  \
# 2  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 3                                    $23,332,172,582
# 4  The Infinity Saga $22,587,903,034 23 $982,082,...
# 5                                    $22,587,903,034
# ...

# %%
#resetting the index of the columns
data.reset_index(drop=True,inplace=True)
data.head()
# Out:
#                                                 Rank  \
# 0  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 1                                                  1
# 2  The Infinity Saga $22,587,903,034 23 $982,082,...
# 3                                                NaN
# 4  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                               Series  \
# 0  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 1                         Marvel Cinematic UniverseS
# 2  The Infinity Saga $22,587,903,034 23 $982,082,...
# 3                                  The Infinity Saga
# 4  Phase Three $13,504,967,341 11 $1,227,724,304 ...
#
#                                Total worldwide gross  \
# 0  1 Marvel Cinematic UniverseS $23,332,172,582 2...
# 1                                    $23,332,172,582
# 2  The Infinity Saga $22,587,903,034 23 $982,082,...
# 3                                    $22,587,903,034
# ...

# %% [markdown]
# # removing the non-numeric rows in the column='Rank'

# %%
data_new=data[pd.to_numeric(data['Rank'],errors='coerce').notnull()]
data_new.head(35)
# Out:
#    Rank                                            Series  \
# 1     1                        Marvel Cinematic UniverseS
# 6     1                          Avengers: Endgame (2019)
# 7     2                     Avengers: Infinity War (2018)
# 8     3                              Black Panther (2018)
# 9     4                 Captain America: Civil War (2016)
# 10    5                  Spider-Man: Far From Home (2019)
# 11    6                             Captain Marvel (2019)
# 12    7                     Spider-Man: Homecoming (2017)
# 13    8             Guardians of the Galaxy Vol. 2 (2017)
# 14    9                             Thor: Ragnarok (2017)
# 15   10                             Doctor Strange (2016)
# 16   11                       Ant-Man and the Wasp (2018)
# 19    1                    Avengers: Age of Ultron (2015)
# 20    2                                 Iron Man 3 (2013)
# 21    3                    Guardians of the Galaxy (2014)
# ...

# %%
#dropping all the Nan values as they imply sub-category of  a film series

data_new.dropna(inplace=True)

# %%
#resetting the index of the rows

data_new.reset_index(inplace=True,drop=True)
data_new.head()
# Out:
#   Rank                      Series Total worldwide gross No. of films  \
# 0    1  Marvel Cinematic UniverseS       $23,332,172,582           25
# 1    2                   Star Wars       $10,315,843,646           12
# 2    3             Wizarding World        $9,245,613,281           10
# 3    4                    Avengers        $7,770,077,764            4
# 4    5                  Spider-Man        $7,213,542,971            9
#
#   Average of films                              Highest-grossing film
# 0     $933,286,903                 Avengers: Endgame ($2,797,501,328)
# 1     $859,653,637                 The Force Awakens ($2,068,223,624)
# 2     $924,561,328  Harry Potter and the Deathly Hallows – Part 2 ...
# 3   $1,942,519,441                           Endgame ($2,797,501,328)
# 4     $801,504,775                     Far From Home ($1,131,928,519)

# %%
# keeping the column "Rank" as the new index of the rows

data_new.set_index("Rank",inplace=True)

# %%
data_new.head()
# Out:
#                           Series Total worldwide gross No. of films  \
# Rank
# 1     Marvel Cinematic UniverseS       $23,332,172,582           25
# 2                      Star Wars       $10,315,843,646           12
# 3                Wizarding World        $9,245,613,281           10
# 4                       Avengers        $7,770,077,764            4
# 5                     Spider-Man        $7,213,542,971            9
#
#      Average of films                              Highest-grossing film
# Rank
# 1        $933,286,903                 Avengers: Endgame ($2,797,501,328)
# 2        $859,653,637                 The Force Awakens ($2,068,223,624)
# 3        $924,561,328  Harry Potter and the Deathly Hallows – Part 2 ...
# 4      $1,942,519,441                           Endgame ($2,797,501,328)
# 5        $801,504,775                     Far From Home ($1,131,928,519)
